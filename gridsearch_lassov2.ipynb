# %%
import sklearn
import warnings
import numpy as np
import sklearn.model_selection as ms
from sklearn import linear_model
import pandas as pd
data = pd.read_csv('compiled_with_season.csv')

# %%
pd.set_option('display.max_columns',None)
data.head()
data = data.fillna(0)

# %%
target = data['LogSalePrice']
features = data.drop(columns = ['LogSalePrice'])

# %%
# setting lasso parameters for randomized search
lasso = linear_model.Lasso()
lasso.set_params(normalize = True, max_iter = 100000)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=100000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
# running gridsearch to obtain ideal alpha
from sklearn.model_selection import GridSearchCV
from sklearn import datasets
param_grid = [{'alpha':list(np.arange(.0001,.001,.0001))}]

para_search = GridSearchCV(estimator = lasso, param_grid = param_grid, scoring = 'r2', return_train_score = True)
para_search = para_search.fit(features,target)

# %%
# running randomizedsearch to obtain ideal alpha
from sklearn.model_selection import RandomizedSearchCV
param_distributions = [{'alpha':list(np.arange(.000001,.001,.000001))}]

random_search = RandomizedSearchCV(estimator = lasso, param_distributions = param_distributions, scoring = 'r2', return_train_score = True, n_iter = 500)
random_search = random_search.fit(features,target)

# %%
# results from randomized search
print(random_search.best_score_)
print(random_search.best_params_)
print(random_search.best_index_)
# Out:
# 0.8793459006658522
# {'alpha': 4.399999999999999e-05}
# 145

# %%
# coeficients from randomized search
best_lasso = linear_model.Lasso()
best_lasso.set_params(normalize = True, alpha = 4.399999999999999e-05)
best_lasso.fit(features,target)
best_lasso.coef_
# Out:
# array([-0.00000000e+00,  2.73208000e-02,  0.00000000e+00,  6.50577317e-03,
#         4.28902542e-02, -2.53529229e-02, -0.00000000e+00, -3.87079947e-04,
#        -6.95618646e-02, -5.46840226e-02,  8.47352218e-03,  4.97035984e-02,
#         6.87041639e-03,  1.45439138e-01, -7.05652049e-02, -0.00000000e+00,
#        -1.12598067e-02, -1.75583829e-01, -6.78617900e-03, -0.00000000e+00,
#        -2.77962137e-02, -2.94635017e-03,  7.22359259e-02,  1.01533721e-01,
#        -3.67766384e-02, -0.00000000e+00,  3.55076871e-03,  6.63828064e-02,
#         1.23000260e-01,  3.77775229e-03,  4.18334388e-02, -0.00000000e+00,
#         5.91331071e-02,  1.26970634e-02, -1.12381315e-02, -1.69735163e-02,
#         4.09744347e-02, -0.00000000e+00,  0.00000000e+00,  1.02893108e-06,
#        -8.08729370e-05,  1.80206343e-02,  1.04355518e-04,  8.24818660e-05,
#         6.94768825e-05,  1.74188904e-04,  2.74658309e-04, -9.85545731e-02,
#        -0.00000000e+00,  2.52603906e-05,  0.00000000e+00,  5.47498383e-02,
#        -0.00000000e+00,  1.60513206e-02, -0.00000000e+00, -0.00000000e+00,
#         3.60753803e-02, -5.11288019e-02,  3.23982582e-02,  0.00000000e+00,
#         5.10149191e-02,  0.00000000e+00, -1.22952023e-02,  1.05092007e-02,
#         2.18534462e-02,  0.00000000e+00, -2.30661423e-02,  0.00000000e+00,
#         1.97708391e-04,  0.00000000e+00, -6.67040371e-02, -5.74797127e-03,
#        -2.26912213e-02, -0.00000000e+00,  6.08174210e-02,  7.21973138e-02,
#         3.69179857e-02,  4.37898230e-02,  9.46045637e-03,  0.00000000e+00,
#        -0.00000000e+00,  5.00662941e-02, -6.40673100e-02, -0.00000000e+00,
#         2.09211373e-04,  1.57823456e-02,  2.07105185e-02,  4.68040027e-02,
#         8.80117488e-03,  3.56126206e-02, -2.54969904e-03,  5.95093802e-02,
#        -4.17667305e-02,  0.00000000e+00, -2.40254738e-02, -5.79936293e-02,
#        -1.78019325e-01, -0.00000000e+00,  0.00000000e+00, -3.30978882e-02,
#        -2.24554238e-01,  4.85475070e-02,  7.04008864e-02, -6.80770682e-02,
#         2.41244101e-02, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  1.46996136e-03, -6.95260068e-03,
#         5.96450170e-04,  8.48016088e-02,  3.44777958e-02,  8.94031850e-03,
#        -0.00000000e+00, -3.70008105e-01,  0.00000000e+00, -2.49233406e-02,
#         4.85303912e-02, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         4.52674993e-03, -2.76207902e-02,  0.00000000e+00, -1.65253508e-01,
#        -6.71963884e-02, -2.60199903e-02,  0.00000000e+00,  4.89197482e-02,
#         1.16745576e-01,  1.99087107e-01,  8.01941519e-02,  0.00000000e+00,
#         3.01263443e-02,  7.98943520e-02, -1.45379545e-02,  0.00000000e+00,
#         1.47680825e-01, -4.58274411e-02,  5.47598004e-02,  0.00000000e+00,
#        -1.24384593e-02,  7.89528720e-04,  0.00000000e+00, -2.33211941e-02,
#         7.68875707e-03, -1.49611152e-02, -2.72704540e-02, -2.18511348e-02,
#         0.00000000e+00,  0.00000000e+00,  2.02502901e-02,  1.72457585e-02,
#        -0.00000000e+00,  5.16369533e-02, -2.61960031e-02, -0.00000000e+00,
#         3.86613473e-03, -7.20668170e-02,  6.75984086e-04, -0.00000000e+00,
#         1.38822682e-02,  1.41378879e-02])

# %%
# list of coefficients with column name
list(zip(list(features.columns),best_lasso.coef_))
# Out:
# [('LotShape_IR1', -0.0),
#  ('LotShape_IR2', 0.027320799960905407),
#  ('LotShape_Reg', 0.0),
#  ('LotConfig_Corner', 0.006505773167635052),
#  ('LotConfig_CulDSac', 0.04289025419643521),
#  ('LotConfig_FR2', -0.025352922931321138),
#  ('LotConfig_Inside', -0.0),
#  ('Neighborhood_Blmngtn', -0.00038707994672150373),
#  ('Neighborhood_Blueste', -0.06956186463524947),
#  ('Neighborhood_BrDale', -0.05468402261326364),
#  ('Neighborhood_BrkSide', 0.008473522181700296),
#  ('Neighborhood_ClearCr', 0.04970359844134408),
#  ('Neighborhood_CollgCr', 0.0068704163855524665),
#  ('Neighborhood_Crawfor', 0.14543913787941565),
#  ('Neighborhood_Edwards', -0.07056520493060316),
#  ('Neighborhood_Gilbert', -0.0),
#  ('Neighborhood_IDOTRR', -0.011259806662641317),
#  ('Neighborhood_MeadowV', -0.17558382917321494),
#  ('Neighborhood_Mitchel', -0.0067861789954561024),
#  ('Neighborhood_NAmes', -0.0),
#  ('Neighborhood_NPkVill', -0.027796213663783695),
#  ('Neighborhood_NWAmes', -0.0029463501680312377),
#  ('Neighborhood_NoRidge', 0.07223592589047186),
#  ('Neighborhood_NridgHt', 0.10153372142541657),
#  ('Neighborhood_OldTown', -0.036776638442352516),
#  ('Neighborhood_Sawyer', -0.0),
#  ('Neighborhood_SawyerW', 0.0035507687113769107),
#  ('Neighborhood_Somerst', 0.06638280642846844),
#  ('Neighborhood_StoneBr', 0.12300026048252086),
#  ('Neighborhood_Timber', 0.003777752291154146),
#  ('Neighborhood_Veenker', 0.04183343878941727),
#  ('Condition1_Feedr', -0.0),
#  ('Condition1_Norm', 0.05913310712056015),
#  ('Condition1_PosA', 0.01269706336482725),
#  ('Condition1_PosN', -0.011238131497706609),
#  ('Condition1_RRAe', -0.01697351628474363),
#  ('Condition1_RRAn', 0.04097443474976904),
#  ('Condition1_RRNe', -0.0),
#  ('Condition1_RRNn', 0.0),
#  ('LotArea', 1.028931080412977e-06),
#  ('LotFrontage', -8.087293698576274e-05),
#  ('PavedDrive', 0.018020634251339762),
#  ('WoodDeckSF', 0.00010435551846458772),
#  ('OpenPorchSF', 8.248186597428794e-05),
#  ('EnclosedPorch', 6.94768825371005e-05),
#  ('3SsnPorch', 0.00017418890394039411),
#  ('ScreenPorch', 0.0002746583094965927),
#  ('Pool', -0.09855457307982453),
#  ('Fence', -0.0),
#  ('TotalBsmtSF', 2.5260390649978493e-05),
#  ('BsmtHasBath', 0.0),
#  ('BsmtQual_Ex', 0.05474983831017887),
#  ('BsmtQual_Fa', -0.0),
#  ('BsmtQual_Gd', 0.016051320551014096),
#  ('BsmtQual_TA', -0.0),
#  ('BsmtCond_Fa', -0.0),
#  ('BsmtCond_Gd', 0.03607538029827483),
#  ('BsmtCond_Po', -0.05112880190132662),
#  ('BsmtCond_TA', 0.03239825816432668),
#  ('BsmtExposure_Av', 0.0),
#  ('BsmtExposure_Gd', 0.05101491911204661),
#  ('BsmtExposure_Mn', 0.0),
#  ('BsmtExposure_No', -0.012295202337364274),
#  ('BsmtFinType1_ALQ', 0.010509200696967314),
#  ('BsmtFinType1_GLQ', 0.02185344620070875),
#  ('BsmtFinType1_Rec', 0.0),
#  ('BsmtFinType1_Unf', -0.023066142333170243),
#  ('MiscVal', 0.0),
#  ('MoSold', 0.00019770839124755418),
#  ('MiscFeature_Gar2', 0.0),
#  ('MiscFeature_Othr', -0.06670403710469906),
#  ('MiscFeature_Shed', -0.005747971272355049),
#  ('MiscFeature_TenC', -0.022691221337981158),
#  ('SaleType_COD', -0.0),
#  ('SaleType_CWD', 0.060817420991619575),
#  ('SaleType_Con', 0.07219731378300903),
#  ('SaleType_New', 0.036917985711648796),
#  ('SaleType_Oth', 0.04378982302273453),
#  ('SaleCondition_AdjLand', 0.00946045637110177),
#  ('SaleCondition_Partial', 0.0),
#  ('BsmtFinType1_Low', -0.0),
#  ('SaleType_LowCon', 0.050066294054301505),
#  ('SaleCondition_Other', -0.06406731002629008),
#  ('lowqualfinsf', -0.0),
#  ('highqualsf', 0.00020921137326681175),
#  ('bedroomabvgr', 0.01578234564286046),
#  ('tot_halfbath', 0.02071051854401993),
#  ('tot_fullbath', 0.046804002738210546),
#  ('extra_rooms', 0.008801174878492721),
#  ('fireplace_binary', 0.03561262057487413),
#  ('kitchenabvgr', -0.002549699042603544),
#  ('kitchenqual_Ex', 0.059509380178595195),
#  ('kitchenqual_Fa', -0.041766730542701525),
#  ('kitchenqual_Gd', 0.0),
#  ('kitchenqual_TA', -0.024025473834428435),
#  ('functional_Maj1', -0.05799362931323224),
#  ('functional_Maj2', -0.17801932543278373),
#  ('functional_Min1', -0.0),
#  ('functional_Min2', 0.0),
#  ('functional_Mod', -0.03309788816014367),
#  ('functional_Sev', -0.22455423802111943),
#  ('functional_Typ', 0.048547506961245705),
#  ('garagecars', 0.07040088636159691),
#  ('garagetype_2Types', -0.06807706822441846),
#  ('garagetype_Attchd', 0.02412441008078616),
#  ('garagetype_Basment', -0.0),
#  ('garagetype_BuiltIn', -0.0),
#  ('garagetype_CarPort', -0.0),
#  ('garagetype_Detchd', 0.0),
#  ('garagefinish_Fin', 0.0),
#  ('garagefinish_RFn', 0.001469961359406416),
#  ('garagefinish_Unf', -0.006952600683998276),
#  ('Electrical_Y', 0.0005964501701466816),
#  ('CentralAir_Y', 0.08480160880029974),
#  ('Heating_Ex', 0.034477795828504756),
#  ('Heating_Gd', 0.008940318495428184),
#  ('Heating_TA', -0.0),
#  ('MSZoning_C', -0.37000810474449836),
#  ('MSZoning_RL', 0.0),
#  ('MSZoning_RM/RH', -0.024923340635129108),
#  ('BldgType_1Fam', 0.048530391220338455),
#  ('BldgType_TwnhsE', -0.0),
#  ('HouseStyle_1.5Fin', -0.0),
#  ('HouseStyle_1.5Unf', -0.0),
#  ('HouseStyle_1Story', 0.004526749934588411),
#  ('HouseStyle_2Story', -0.027620790228983068),
#  ('HouseStyle_Other', 0.0),
#  ('OverallQual_3', -0.16525350812223488),
#  ('OverallQual_4', -0.06719638837259594),
#  ('OverallQual_5', -0.026019990336520925),
#  ('OverallQual_6', 0.0),
#  ('OverallQual_7', 0.048919748187508126),
#  ('OverallQual_8', 0.11674557635446774),
#  ('OverallQual_9', 0.19908710704578844),
#  ('OverallQual_10', 0.08019415185707594),
#  ('OverallCond_4', 0.0),
#  ('OverallCond_5', 0.030126344271370682),
#  ('OverallCond_6', 0.07989435197866752),
#  ('RoofStyle_Gable', -0.014537954537764434),
#  ('RoofStyle_Hip', 0.0),
#  ('RoofMatl_WdShngl', 0.14768082532762433),
#  ('Exterior_AsbShng', -0.04582744111138255),
#  ('Exterior_BrkFace', 0.054759800381999485),
#  ('Exterior_CemntBd', 0.0),
#  ('Exterior_HdBoard', -0.012438459306935084),
#  ('Exterior_MetalSd', 0.0007895287197785198),
#  ('Exterior_Plywood', 0.0),
#  ('Exterior_Stucco', -0.023321194124723804),
#  ('Exterior_VinylSd', 0.007688757069190429),
#  ('Exterior_Wd Sdng', -0.014961115197180805),
#  ('Exterior_WdShing', -0.027270453986925708),
#  ('MasVnrType_BrkCmn', -0.0218511347994518),
#  ('MasVnrType_BrkFace', 0.0),
#  ('MasVnrType_Stone', 0.0),
#  ('ExterQual_Ex', 0.020250290087237968),
#  ('ExterQual_Gd', 0.017245758451082418),
#  ('ExterQual_TA', -0.0),
#  ('ExterCond_Gd', 0.05163695334636547),
#  ('Foundation_BrkTil', -0.026196003072443592),
#  ('Foundation_CBlock', -0.0),
#  ('Foundation_PConc', 0.00386613473180675),
#  ('Foundation_Slab', -0.07206681704257359),
#  ('YearBuilt', 0.0006759840864372419),
#  ('Fall', -0.0),
#  ('Spring', 0.013882268239944267),
#  ('Summer', 0.014137887909450308)]

# %%
# transforming coefficients to percent impact on saleprice
import math as ma
coefs_as_percent = list(map(lambda x: (ma.exp(x)-1)*100,best_lasso.coef_))

# %%
coef_list = list(zip(list(features.columns),coefs_as_percent))

# %%
# creating dataframe of betas as percent impact on salesprice and name of corresponding variable column
di = {}
for (a,b) in coef_list:
    di.setdefault(a,[]).append(b)
coef_df = pd.DataFrame.from_dict(di)
coef_df = coef_df.transpose().sort_values(by = 0)
coef_df.to_csv('coef_df.csv')

# %%
pd.set_option('display.min_rows',500)
# pd.set_option('display.max_rows',500)

# %%
# displaying above dataframe in alphabetical order of variable name for analysis
coef_df.sort_index()
# Out:
#                                0
# 3SsnPorch               0.017420
# BldgType_1Fam           4.972727
# BldgType_TwnhsE         0.000000
# BsmtCond_Fa             0.000000
# BsmtCond_Gd             3.673399
# BsmtCond_Po            -4.984372
# BsmtCond_TA             3.292880
# BsmtExposure_Av         0.000000
# BsmtExposure_Gd         5.233859
# BsmtExposure_Mn         0.000000
# BsmtExposure_No        -1.221993
# BsmtFinType1_ALQ        1.056462
# BsmtFinType1_GLQ        2.209398
# BsmtFinType1_Low        0.000000
# BsmtFinType1_Rec        0.000000
# BsmtFinType1_Unf       -2.280215
# BsmtHasBath             0.000000
# BsmtQual_Ex             5.627634
# BsmtQual_Fa             0.000000
# BsmtQual_Gd             1.618084
# BsmtQual_TA             0.000000
# CentralAir_Y            8.850110
# Condition1_Feedr        0.000000
# Condition1_Norm         6.091645
# Condition1_PosA         1.277801
# Condition1_PosN        -1.117522
# Condition1_RRAe        -1.683028
# Condition1_RRAn         4.182547
# Condition1_RRNe         0.000000
# Condition1_RRNn         0.000000
# Electrical_Y            0.059663
# EnclosedPorch           0.006948
# ExterCond_Gd            5.299339
# ExterQual_Ex            2.045672
# ExterQual_Gd            1.739533
# ExterQual_TA            0.000000
# Exterior_AsbShng       -4.479322
# Exterior_BrkFace        5.628686
# Exterior_CemntBd        0.000000
# Exterior_HdBoard       -1.236142
# Exterior_MetalSd        0.078984
# Exterior_Plywood        0.000000
# Exterior_Stucco        -2.305136
# Exterior_VinylSd        0.771839
# Exterior_Wd Sdng       -1.484975
# Exterior_WdShing       -2.690197
# Fall                    0.000000
# Fence                   0.000000
# Foundation_BrkTil      -2.585586
# Foundation_CBlock       0.000000
# Foundation_PConc        0.387362
# Foundation_Slab        -6.953128
# Heating_Ex              3.507905
# Heating_Gd              0.898040
# Heating_TA              0.000000
# HouseStyle_1.5Fin       0.000000
# HouseStyle_1.5Unf       0.000000
# HouseStyle_1Story       0.453701
# HouseStyle_2Story      -2.724282
# HouseStyle_Other        0.000000
# LotArea                 0.000103
# LotConfig_Corner        0.652698
# LotConfig_CulDSac       4.382333
# LotConfig_FR2          -2.503424
# LotConfig_Inside        0.000000
# LotFrontage            -0.008087
# LotShape_IR1            0.000000
# LotShape_IR2            2.769744
# LotShape_Reg            0.000000
# MSZoning_C            -30.927127
# MSZoning_RL             0.000000
# MSZoning_RM/RH         -2.461532
# MasVnrType_BrkCmn      -2.161413
# MasVnrType_BrkFace      0.000000
# MasVnrType_Stone        0.000000
# MiscFeature_Gar2        0.000000
# MiscFeature_Othr       -6.452797
# MiscFeature_Shed       -0.573148
# MiscFeature_TenC       -2.243571
# MiscVal                 0.000000
# MoSold                  0.019773
# Neighborhood_Blmngtn   -0.038701
# Neighborhood_Blueste   -6.719758
# Neighborhood_BrDale    -5.321574
# Neighborhood_BrkSide    0.850952
# Neighborhood_ClearCr    5.095954
# Neighborhood_CollgCr    0.689407
# Neighborhood_Crawfor   15.654734
# Neighborhood_Edwards   -6.813302
# Neighborhood_Gilbert    0.000000
# Neighborhood_IDOTRR    -1.119665
# Neighborhood_MeadowV  -16.103294
# Neighborhood_Mitchel   -0.676320
# Neighborhood_NAmes      0.000000
# Neighborhood_NPkVill   -2.741345
# Neighborhood_NWAmes    -0.294201
# Neighborhood_NoRidge    7.490891
# Neighborhood_NridgHt   10.686724
# Neighborhood_OldTown   -3.610859
# Neighborhood_Sawyer     0.000000
# Neighborhood_SawyerW    0.355708
# Neighborhood_Somerst    6.863572
# Neighborhood_StoneBr   13.088472
# Neighborhood_Timber     0.378490
# Neighborhood_Veenker    4.272079
# OpenPorchSF             0.008249
# OverallCond_4           0.000000
# OverallCond_5           3.058473
# OverallCond_6           8.317263
# OverallQual_10          8.349741
# OverallQual_3         -15.232122
# OverallQual_4          -6.498844
# OverallQual_5          -2.568439
# OverallQual_6           0.000000
# OverallQual_7           5.013607
# OverallQual_8          12.383346
# OverallQual_9          22.028826
# PavedDrive              1.818399
# Pool                   -9.385376
# RoofMatl_WdShngl       15.914287
# RoofStyle_Gable        -1.443279
# RoofStyle_Hip           0.000000
# SaleCondition_AdjLand   0.950535
# SaleCondition_Other    -6.205814
# SaleCondition_Partial   0.000000
# SaleType_COD            0.000000
# SaleType_CWD            6.270487
# SaleType_Con            7.486741
# SaleType_LowCon         5.134079
# SaleType_New            3.760792
# SaleType_Oth            4.476275
# ScreenPorch             0.027470
# Spring                  1.397907
# Summer                  1.423830
# TotalBsmtSF             0.002526
# WoodDeckSF              0.010436
# YearBuilt               0.067621
# bedroomabvgr            1.590754
# extra_rooms             0.884002
# fireplace_binary        3.625435
# functional_Maj1        -5.634404
# functional_Maj2       -16.307375
# functional_Min1         0.000000
# functional_Min2         0.000000
# functional_Mod         -3.255615
# functional_Sev        -20.112775
# functional_Typ          4.974524
# garagecars              7.293822
# garagefinish_Fin        0.000000
# garagefinish_RFn        0.147104
# garagefinish_Unf       -0.692849
# garagetype_2Types      -6.581153
# garagetype_Attchd       2.441776
# garagetype_Basment      0.000000
# garagetype_BuiltIn      0.000000
# garagetype_CarPort      0.000000
# garagetype_Detchd       0.000000
# highqualsf              0.020923
# kitchenabvgr           -0.254645
# kitchenqual_Ex          6.131572
# kitchenqual_Fa         -4.090652
# kitchenqual_Gd          0.000000
# kitchenqual_TA         -2.373916
# lowqualfinsf            0.000000
# tot_fullbath            4.791660
# tot_halfbath            2.092647

# %%
target = target.apply(lambda x: ma.exp(x))
