# %% [markdown]
# # After Lasso Test.csv Formatting

# %%
train_df = pd.read_csv("Data/test.csv")
train_df = train_df.set_index("Id")
train_df = train_df.drop(["Condition2", "Street", "Alley", "LandSlope", "LandContour", "PoolQC", "Fence",\
                          "KitchenAbvGr","GarageArea", "BsmtFinType2", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF",\
                          "YrSold", "MSSubClass", "YearRemodAdd", "Exterior2nd", "GarageYrBlt", "HouseStyle",\
                          "MasVnrArea", "Utilities", "Heating", "Electrical","MoSold", "LotFrontage",\
                          "MasVnrType", "MiscFeature", "PavedDrive", "PoolArea", "RoofStyle","GarageFinish",\
                          "KitchenAbvGr", "LowQualFinSF", "GarageQual", "GarageCond", "1stFlrSF", "2ndFlrSF",\
                         "FireplaceQu"], axis = 1)

# %%
train_df.head()
# Out:
#      MSZoning  LotArea LotShape LotConfig Neighborhood Condition1 BldgType  \
# Id
# 1461       RH    11622      Reg    Inside        NAmes      Feedr     1Fam
# 1462       RL    14267      IR1    Corner        NAmes       Norm     1Fam
# 1463       RL    13830      IR1    Inside      Gilbert       Norm     1Fam
# 1464       RL     9978      IR1    Inside      Gilbert       Norm     1Fam
# 1465       RL     5005      IR1    Inside      StoneBr       Norm   TwnhsE
#
#       OverallQual  OverallCond  YearBuilt  ... GarageType GarageCars  \
# Id                                         ...
# 1461            5            6       1961  ...     Attchd        1.0
# 1462            6            6       1958  ...     Attchd        1.0
# 1463            5            5       1997  ...     Attchd        2.0
# 1464            6            6       1998  ...     Attchd        2.0
# 1465            8            5       1992  ...     Attchd        2.0
#
# ...

# %%
train_df["FullBath"] = train_df["FullBath"] + train_df["BsmtFullBath"] 
train_df["HalfBath"] = train_df["HalfBath"] + train_df["BsmtHalfBath"]

# %%
train_df = train_df.drop(["BsmtFullBath", "BsmtHalfBath"], axis = 1)

# %%
train_df.columns
# Out:
# Index(['MSZoning', 'LotArea', 'LotShape', 'LotConfig', 'Neighborhood',
#        'Condition1', 'BldgType', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'RoofMatl', 'Exterior1st', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'TotalBsmtSF',
#        'HeatingQC', 'CentralAir', 'GrLivArea', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional',
#        'Fireplaces', 'GarageType', 'GarageCars', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'MiscVal', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
train_df.isnull().sum()
# Out:
# MSZoning          4
# LotArea           0
# LotShape          0
# LotConfig         0
# Neighborhood      0
# Condition1        0
# BldgType          0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# RoofMatl          0
# Exterior1st       1
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual         44
# BsmtCond         45
# BsmtExposure     44
# BsmtFinType1     42
# TotalBsmtSF       1
# HeatingQC         0
# CentralAir        0
# GrLivArea         0
# FullBath          2
# HalfBath          2
# BedroomAbvGr      0
# KitchenQual       1
# TotRmsAbvGrd      0
# Functional        2
# Fireplaces        0
# GarageType       76
# GarageCars        1
# WoodDeckSF        0
# OpenPorchSF       0
# EnclosedPorch     0
# 3SsnPorch         0
# ScreenPorch       0
# MiscVal           0
# SaleType          1
# SaleCondition     0
# dtype: int64

# %%
train_df[['FullBath', 'HalfBath', 'TotalBsmtSF', 'GarageCars']] = train_df[['FullBath', 'HalfBath', 'TotalBsmtSF', 'GarageCars']].fillna(0)
train_df = train_df.fillna("None")

# %%
pd.set_option('display.min_rows',500)
np.sum(train_df.isnull())
# Out:
# MSZoning         0
# LotArea          0
# LotShape         0
# LotConfig        0
# Neighborhood     0
# Condition1       0
# BldgType         0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# RoofMatl         0
# Exterior1st      0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# TotalBsmtSF      0
# HeatingQC        0
# CentralAir       0
# GrLivArea        0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# GarageType       0
# GarageCars       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# MiscVal          0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
def frame_to_dict (x): 
    all_list = list(x)
    all_dict = {}
    for thing in all_list:
        all_dict[thing] = all_list.count(thing)
    return all_dict

# %%
def condense_name (x, L, other = "Other"):
    to_condense = list(x)
    for i in range(len(to_condense)):
        if to_condense[i] not in L:
            to_condense[i] = other
    return to_condense

# test = train_df["BsmtExposure"]
# print(frame_to_dict(test))
# print(frame_to_dict(condense_name(test, ["Gd", "Mn"])))

# test_2 = [1, 2, 3, 4]
# print(condense_name(test_2, [2, 3]))

#print(frame_to_dict(condense_name(train_df["BsmtQual"], ["Ex", "TA"], "Something")))

train_df.BldgType = condense_name(train_df["BldgType"], ["1Fam"], "Other")
train_df.BsmtExposure = condense_name(train_df["BsmtExposure"], ["Gd", "None"], "NoGd")
train_df.BsmtQual = condense_name(train_df["BsmtQual"], ["Ex", "None"], "Other")
train_df.Condition1 = condense_name(train_df["Condition1"], ["Norm", "RRAn"], "Other")
train_df.Exterior1st = condense_name(train_df["Exterior1st"], ["AsbShng", "BrkFace"], "Other")
train_df.Foundation = condense_name(train_df["Foundation"], ["BrkTil", "Slab"], "Other")
train_df.HeatingQC = condense_name(train_df["HeatingQC"], ["Ex"], "NotEx")
train_df.MSZoning = condense_name(train_df["MSZoning"], ["RL", "C (all)"], "Other")
train_df.SaleCondition = condense_name(train_df["SaleCondition"], ["Normal"], "Other")
train_df.GarageType = condense_name(train_df["GarageType"], ["Attchd", "None"], "Other")

train_df.loc[ train_df.OverallQual == 1, 'OverallQual'] = 2
train_df.loc[ train_df.OverallCond == 9, 'OverallCond'] = 5
train_df.loc[ train_df.OverallCond == 7, 'OverallCond'] = 6
train_df.loc[ train_df.OverallCond == 8, 'OverallCond'] = 6
train_df.loc[ train_df.OverallCond == 1, 'OverallCond'] = 2
train_df.loc[ train_df.OverallCond == 2, 'OverallCond'] = 3
train_df.loc[ train_df.RoofMatl == 'Metal', 'RoofMatl'] = 'Other'
train_df.loc[ train_df.RoofMatl == 'WdShake', 'RoofMatl'] = 'Other'
train_df.loc[ train_df.RoofMatl == 'Membran', 'RoofMatl'] = 'Other'
train_df.loc[ train_df.RoofMatl == 'Tar&Grv', 'RoofMatl'] = 'Other'
train_df.loc[ train_df.RoofMatl == 'Roll', 'RoofMatl'] = 'Other'
train_df.loc[ train_df.RoofMatl == 'ClyTile', 'RoofMatl'] = 'Other'
train_df.loc[ train_df.RoofMatl == 'CompShg', 'RoofMatl'] = 'Other'
train_df.loc[ train_df.ExterCond == 'Po', 'ExterCond'] = 'Fa'
train_df.loc[ train_df.ExterCond == 'TA', 'ExterCond'] = 'Gd'
train_df.loc[ train_df.ExterCond == 'Ex', 'ExterCond'] = 'Gd'
train_df.loc[ train_df.Foundation == 'Wood', 'Foundation'] = 'Other'
train_df.loc[ train_df.Foundation == 'Stone', 'Foundation'] = 'Other'

#bsmt_has_bath_list = [bsmt_has_bath_list[x] - bsmt_has_bath_list[x] + 1 if bsmt_has_bath_list[x] >= 1 else bsmt_has_bath_list[x] * 0 for x in range(len(bsmt_has_bath_list))]

# %%
train_df.shape
# Out:
# (1459, 40)

# %%
train_df.head()
# Out:
#      MSZoning  LotArea LotShape LotConfig Neighborhood Condition1 BldgType  \
# Id
# 1461    Other    11622      Reg    Inside        NAmes      Other     1Fam
# 1462       RL    14267      IR1    Corner        NAmes       Norm     1Fam
# 1463       RL    13830      IR1    Inside      Gilbert       Norm     1Fam
# 1464       RL     9978      IR1    Inside      Gilbert       Norm     1Fam
# 1465       RL     5005      IR1    Inside      StoneBr       Norm    Other
#
#       OverallQual  OverallCond  YearBuilt  ... GarageType GarageCars  \
# Id                                         ...
# 1461            5            6       1961  ...     Attchd        1.0
# 1462            6            6       1958  ...     Attchd        1.0
# 1463            5            5       1997  ...     Attchd        2.0
# 1464            6            6       1998  ...     Attchd        2.0
# 1465            8            5       1992  ...     Attchd        2.0
#
# ...

# %%
split = train_df.columns.to_series().groupby(train_df.dtypes).groups
split

categories = ['MSZoning', 'LotShape', 'LotConfig', 'Neighborhood', 'Condition1',
        'BldgType', 'RoofMatl', 'Exterior1st', 'ExterQual', 'ExterCond',
        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
        'HeatingQC', 'CentralAir', 'KitchenQual', 'Functional', 'GarageType',
        'SaleType', 'SaleCondition', "YearBuilt"]


from sklearn.preprocessing import LabelEncoder # importing encoder library

label = LabelEncoder() # creating an instance of the class LabelEncoder
# looping through every column and changing the values into ordinal
for column in categories:
    train_df[column] = label.fit_transform(train_df[column])

# %%
train_df = train_df.reset_index()
train_df.head()
# Out:
#      Id  MSZoning  LotArea  LotShape  LotConfig  Neighborhood  Condition1  \
# 0  1461         1    11622         3          4            12           1
# 1  1462         2    14267         0          0            12           0
# 2  1463         2    13830         0          4             8           0
# 3  1464         2     9978         0          4             8           0
# 4  1465         2     5005         0          4            22           0
#
#    BldgType  OverallQual  OverallCond  ...  GarageType  GarageCars  \
# 0         0            5            6  ...           0         1.0
# 1         0            6            6  ...           0         1.0
# 2         0            5            5  ...           0         2.0
# 3         0            6            6  ...           0         2.0
# 4         1            8            5  ...           0         2.0
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  MiscVal  \
# ...

# %%
train_df.to_csv("after_lasso_test.csv", index = False)
